# %%
#Importação das bibliotecas necessárias - Essa célula deve ser executada antes de todas as outras
import skimage as sk
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Parte 1.1 - Imagens coloridas
#
# ## Alteração do item a

# %%
# directory = os.path.dirname("__file__")
# img_dir = os.path.join(directory, os.pardir, 'color', 'baboon.png')

img = io.imread('../color/baboon.png')

if img is None:
    sys.exit("Could not read the image.")
 
#Alteração de imagens coloridas segundo a seguinte fórmula:
#   R’ = 0.393R + 0.769G + 0.189B
#   G’ = 0.349R + 0.686G + 0.168B
#   B’ = 0.272R + 0.534G + 0.131B   

row, col, depth = np.shape(img)

new_img = np.zeros(np.shape(img), dtype=np.uint16)

#Transformação das fórmulas em matriz
weight = np.array([[0.393, 0.769, 0.189], [0.349, 0.686, 0.168], [0.272, 0.534, 0.131]])

#Aplicação do filtro de maneira vetorizada
new_img[:,:,0] = img[:,:,0] * weight[0][0] + img[:,:,1] * weight[0][1] + img[:,:,2] * weight[0][2]
new_img[:,:,1] = img[:,:,0] * weight[1][0] + img[:,:,1] * weight[1][1] + img[:,:,2] * weight[1][2]
new_img[:,:,2] = img[:,:,0] * weight[2][0] + img[:,:,1] * weight[2][1] + img[:,:,2] * weight[2][2]

new_img[new_img > 255] = 255

f, axarr = plt.subplots(1,2)
axarr[0].imshow(img)
axarr[1].imshow(new_img)
plt.show()

# %% [markdown]
# ## Alteração do item b

# %%
img = io.imread('../color/baboon.png')

if img is None:
    sys.exit("Could not read the image.")


#Conversão de imagem RGB para monocromática segundo a seguinte fórmula:
#   I = 0.2989R + 0.5870G + 0.1140B


row, col, depth = np.shape(img)

new_img = np.zeros((row, col), dtype=np.int16)

weight = np.array([0.2989, 0.587, 0.114])

new_img[:,:] = img[:,:,0] * weight[0] + img[:,:,1] * weight[1] + img[:,:,2] * weight[2]

f, axarr = plt.subplots(1,2)
axarr[0].imshow(img)
#aqui é necessário informar ao pyplot que a imagem é monocromática
axarr[1].imshow(new_img, cmap = 'gray')
plt.show()

# %% [markdown]
# # Parte 1.2 - Imagens monocromáticas

# %% [markdown]
# ### Célula para leitura das imagens monocromáticas - precisa ser executada antes daquelas que aplicarão os filtros

# %%
img = io.imread('../mono/seagull.png')

if img is None:
    sys.exit("Could not read the image.")

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)

h1 = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
h2 = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])
h3 = np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]])
h4 = np.ones((3, 3)) * 1/9

def convolution(img, mask):
    pad_size = len(mask[0])//2
    mask_size = len(mask[0])
    p_img = np.pad(img, pad_size)
    row, col = np.shape(img)
    
    new_img = np.zeros((row, col), dtype=np.int32)  
    windows = sk.util.shape.view_as_windows(p_img, (mask_size, mask_size))

    new_img = np.sum(np.multiply(mask, windows[:][:]), axis = (2, 3))
    new_img[new_img < 0] = 0
    new_img[new_img > 255] = 255
    print(new_img[0])
    new_img = new_img.astype(np.uint8)
    
    return new_img

# f, axarr = plt.subplots(1,4, figsize = (15,15))
# axarr[0].imshow(img, cmap = 'gray')
# #aqui é necessário informar ao pyplot que a imagem é monocromática
# axarr[1].imshow(convolution(img, h1), cmap = 'gray')
# axarr[2].imshow(convolution(img, h2), cmap = 'gray')
# axarr[3].imshow(convolution(img, h3), cmap = 'gray')
# plt.show()

print(img[0])
# plt.imshow(img, cmap = 'gray')
# plt.show()
# plt.imshow(convolution(img, h4), cmap = 'gray')
# plt.show()

new_img = convolution(img, h4)
io.imsave("test.png", new_img)
# Out:
# [[0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]]
# [112 112 112 112 112 112 112 112 112 112 104 104 104 104 104 104  96  96
#   96  96  88  88  88  88  88  80  81  77  77  69  69  72  77  77  81  81
#   85  85  81  85  85  85  85  85  85  85  88  88  88  89  89  85  81  81
#   78  77  73  78  81  81  81  89  88  88  88  89  89  89  88  89  89  88
#   93  93  96  93  93  93  93  93  89  85  85  86  86  85  89  93  93  93
#   93  93  93  93  96  96  96  97 101 101  97  96  96  97  97  97  96  93
#   89  89  93  93  93  97  96  97  97  97  97  97  97  97  97  97 101 104
#  104  97  97 101 104 101  93  93  93  93  89  93  93  97  97 101 104 101
#  101  97  97  97 105 105 104 104 105 105 110 112 112 112 112 112 112 112
#  112 112 113 112 112 112 121 112 112 112 112 101 104 104 105 101 101 105
#  105 105 105 110 105 105 105 105 105  97  97  97  97  97  97  97  89  94
#   94  89  89  86  89  93  93  93  97  97 105 105 105 105 105 105 105 105
#  110 110 110 105 110 110 113 110 102  98  97  97  94  94  90  90  86  86
#   86  82  82  78  78  80  82  80  82  86  86  90  94  94  94 102 102 102
#  102 105 106 105 105 106 106 105 102 102 102 102 102 110 106 106 105 106
#  102 102 102 102 102 102 105 102 105 105 102 102 102 102 102 102 102 102
#  102 102 102 110 102 102 102 102 102  98 102 105 105 102 102 105 102 105
#  106 110 110 113 113 114 114 114 114 110 126 110 126 110 126 121 121 122
#  122 122 139 122 121 114 114 114 113 113 113 113 110 110 102 102  94  81
#   74  74  64  56  52  56  56  45  40  33  33  32  32  33  33  33  33  33
#   33  32  32  33  33  37  37  33  33  32  32  32  32  32  32  32  33  33
#   32  32  32  32  32  32  32  32  32  32  32  32  32  32  32  32  32  32
#   25  25  32  32  32  32  32  32  25  25  25  32  25  32  25  25  25  32
#   32  32  32  25  25  29  32  32  32  25  25  32  32  32  32  32  32  32
#   32  32  25  25  32  32  32  32  32  32  32  32  32  32  32  32  32  32
#   32  32  32  32  32  32  32  32  32  32  32  32  32  32  32  32  